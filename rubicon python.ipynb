# %%
print("hello world")
# Out:
# hello world

# %%
c=2.7
print(type(c))
# Out:
# <class 'float'>

# %%
b=int(3.7)
print(type(b))
# Out:
# <class 'int'>

# %%
#if else statement
age=int(input("enter your age"))
iq=int(input("enter your iq"))
if not(age>18) and iq>100:
    print("eligible for licence")
elif age>18 and iq<100:
    print("public threat")
else:
    print("not eligible")
# Out:
# not eligible

# %%
d="hello world"
d.strip()
# Out:
# 'hello world'

# %%
e="hello world"
#e.isalpha()
#e.isdigit()
e.find('l')
# Out:
# 2

# %%
#while statement
f=1
while f<10:
    if f==6:
        continue
    print(f)
    f+=2
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in "hello world":
    print(i)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
for i in range(10,0,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
list1=[red,blue,orange]
list2=["apple","banana","mango"]
for i in list1:
    for j in list2:
        print(i+j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 list1=[red,blue,orange]
#       2 list2=["apple","banana","mango"]
#       3 for i in list1:
#
# NameError: name 'red' is not defined

# %%
print(True+5 ,False+5)
# Out:
# 6 5

# %%
for i in range(3):
    print(bool(i))
# Out:
# False
# True
# True

# %%
a=1
if a:
    print("True branch")
else:
    print("False branch")
# Out:
# True branch

# %%
n=2
while n<10:
    n**=2
    print(n)
# Out:
# 4
# 16

# %%
s="hello"
if "h" in s and "l" not in s:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
num=int(input("Enter a Number:"))
if num%3==0:
    if num%5==0:
        print("divi by both")
    else: 
        print("only by 3")
else:
    print("not divi")
# Out:
# not divi

# %%
x=True
y=False
if x and not y:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
for i in range(1,5):
    print(i*2)
# Out:
# 2
# 4
# 6
# 8

# %%
for i in range(10,3,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4

# %%
for i in range(1,7):
    for j in range(1,2):
        print(i*j)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(1,3):
    for j in range(2,5):
        print(i*j,end=" ")
# Out:
# 2 3 4 4 6 8

# %%
n=0
while n<10:
    if n==5:
        break
    print(n)
    n+=2
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
n=0
while n<6:
    n+=1
    if n%2==0:
        continue
    print(n,end="")
# Out:
# 135

# %%
a=5
b=2
print(a%b)
# Out:
# 1

# %%
#list (mutable)
lst=["abcd","def",1,3,4]
lst.pop()
lst.remove("abcd")
print(lst)
# Out:
# ['def', 1, 3]

# %%
lst.remove("xyz")
print(lst)
# Out:
# ['def', 1, 3]

# %%
lst.append("red")
lst.insert(5,"llm")
print(lst)
# Out:
# ['def', 1, 3, 'red', 'llm']

# %%
lst2=[3,5,6,7,2,1,8]
lst2.sort()
print(lst2)
# Out:
# [1, 2, 3, 5, 6, 7, 8]

# %%
lst3=["apple","mango","banana"]
lst4=['red',"blue","green"]
lst3.sort(reverse=False)
print(lst3)
lst3.extend(lst4)
print(lst3)
print(lst3)
# Out:
# ['apple', 'banana', 'mango']
# ['apple', 'banana', 'mango', 'red', 'blue', 'green']
# ['apple', 'banana', 'mango', 'red', 'blue', 'green']

# %%
#list methods
#remove
#insert
#append
#sort
#reverse
#slicing
#extend
#clear
#del

# %%
#tuple methods
t=(2,3,4,"apple")
t[0]
t[0:4]#Accessing
#Slicing
#Concatenation
#Length
#index
#counting
#nested
t1=(1,2,3,4)
t2=(1,2,3,4)
print(t1==t2)#Comparisons
print(t)
t3=("hello",1,2,3)
t4=("world","prg")
t5=t3+t4
print(t5)
len(t5)
a="hello"
a.count("e")
# Out:
# True
# (2, 3, 4, 'apple')
# ('hello', 1, 2, 3, 'world', 'prg')
# 1

# %%
lst8=[[2,3],[3,4],[4,5]]
lst8[2][1]
# Out:
# 5

# %%
#dictionary(mutable)
dictr={"name":"Suhas","age":21,"address":"engineer"}
dictr.keys()
dictr.get("age")
dictr.update({"name":"abcd"})
#print(dictr)
#dictr.pop("age")
#dictr.clear()
#print(dictr)
dictr1=dictr
dictr2={"name":"abcd","age":211,"address":"being"}
dictr1.update(dictr2)
print(dictr1)
# Out:
# {'name': 'abcd', 'age': 211, 'address': 'being'}

# %%
#F-strings(formatted strings)
b="hello"
a="raj"
print(f'{b} he is {a} {b+a}')
# Out:
# hello he is raj helloraj

# %%
#Functions
def greeting(a,b):
    print(f"hello {a} hi {b}")
    print("welcome")
    print("to Bengaluru")
    print("and have a good day")
greeting("abhinav","goutham")
# Out:
# hello abhinav hi goutham
# welcome
# to Bengaluru
# and have a good day

# %%
def addt(a,b):
    return a+b
addt(int(input("a=")),int(input("b=")))
# Out:
# 170

# %%
lst=[[1,2],[3,4]]
lst[0][1]=99
print(lst)
# Out:
# [[1, 99], [3, 4]]

# %%
t=(1,2,[3,4])
t[2][0]=99
print(t)
# Out:
# (1, 2, [99, 4])

# %%
d1={"a":1,"b":2}
d2={"b":3,"c":4}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
d={"a":1,"b":2}
print("a"in d)
print("c" in d)
# Out:
# True
# False

# %%
lst=[1,2,3,4,5]
for i in lst:
    if i%2==0:
        lst.remove(i)
print(lst)
# Out:
# [1, 3, 5]

# %%
t=(1,2,[3,4,5])
t[2][1]=99
print(t)
# Out:
# (1, 2, [3, 99, 5])

# %%
lst=[(1,2),(4,3),(5,6)]
for a,b in lst:
    if a>b:
        print(f"{a} is greater than {b}")
    else:
        print(f"{b} is greater than {a}")
# Out:
# 2 is greater than 1
# 4 is greater than 3
# 6 is greater than 5

# %%
#sets
s={2,3,4,4,5}
#Characteristics of sets
#Mutable,items not mutable,unordered,no duplicates

# %%
print(type(s))
print(s)
# Out:
# <class 'set'>
# {2, 3, 4, 5}

# %%
s1={2,3,4,3,2,"hello"}
s1.add(5)
s1.remove(4)
s1.pop()
print(s1)
# Out:
# {3, 5, 'hello'}

# %%
s2={1,2,3,4}
s3={3,4,5,6}
s4={4,5,6,7}
a=s2.union(s3)#join/merges without repeatation of values

# %%
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
b=s2.intersection(s3,s4)
print(b)#common values
# Out:
# {4}

# %%
#Functions
def sum_of_list(l):
    return sum(l)
sum_of_list((2,3,4,5,6))
# Out:
# 20

# %%
def check_even_odd(a):
    if a%2==0:
        print("even")
    else:
        print("odd")
check_even_odd(121)
# Out:
# odd

# %%
def largest(a,b,c):
    if a>b and a>c:
        print(f"{a} is greater than {b} and {c}")
    elif b>a and b>c:
        print(f"{b} is greater than {a} and {c}")
    else:
        print(f"{c} is greater than {a} and {b}")
largest(9,23,5)
# Out:
# 23 is greater than 9 and 5

# %%
import pandas as pd
df=pd.read_csv("Sales_April_2019.csv")

# %%
df.head(8)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
# 5   176562        USB-C Charging Cable                1      11.95
# 6   176563  Bose SoundSport Headphones                1      99.99
# 7   176564        USB-C Charging Cable                1      11.95
#
#          Order Date                        Purchase Address
# 0    04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 3  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 4    04/30/19 09:27       333 8th St, Los Angeles, CA 90001
# ...

# %%
df.tail()
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215

# %%
df.head(7)
df.tail(3)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215

# %%
df.describe()#
# Out:
#         Order ID                   Product Quantity Ordered Price Each  \
# count      18324                     18324            18324      18324
# unique     17538                        20                8         18
# top     Order ID  Lightning Charging Cable                1      14.95
# freq          35                      2201            16558       2201
#
#         Order Date  Purchase Address
# count        18324             18324
# unique       13584             17120
# top     Order Date  Purchase Address
# freq            35                35

# %%
df.dtypes#data types
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18382 entries, 0 to 18381
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
df.duplicated().sum()#duplicate values
# Out:
# np.int64(114)

# %%
df.isnull().sum()#count of null values
# Out:
# Order ID            58
# Product             58
# Quantity Ordered    58
# Price Each          58
# Order Date          58
# Purchase Address    58
# dtype: int64

# %%
df=df.rename(columns={"Product":"Item"})

# %%
df=df.rename(columns={"Quantity Ordered":"No. of Orders"})

# %%
df=df.sort_values("Item")

# %%
df["Item"].unique()
# Out:
# array(['USB-C Charging Cable', nan, 'Bose SoundSport Headphones',
#        'Google Phone', 'Wired Headphones', 'Macbook Pro Laptop',
#        'Lightning Charging Cable', '27in 4K Gaming Monitor',
#        'AA Batteries (4-pack)', 'Apple Airpods Headphones',
#        'AAA Batteries (4-pack)', 'iPhone', 'Flatscreen TV',
#        '27in FHD Monitor', '20in Monitor', 'LG Dryer', 'ThinkPad Laptop',
#        'Vareebadd Phone', 'LG Washing Machine', '34in Ultrawide Monitor',
#        'Product'], dtype=object)

# %%
df.drop_duplicates()#remove duplicate values
# Out:
#       Order ID                     Product No. of Orders Price Each  \
# 0       176558        USB-C Charging Cable             2      11.95
# 1          NaN                         NaN           NaN        NaN
# 2       176559  Bose SoundSport Headphones             1      99.99
# 3       176560                Google Phone             1        600
# 4       176560            Wired Headphones             1      11.99
# ...        ...                         ...           ...        ...
# 18378   194090                Google Phone             1        600
# 18379   194091       AA Batteries (4-pack)             1       3.84
# 18380   194092      AAA Batteries (4-pack)             2       2.99
# 18381   194093       AA Batteries (4-pack)             1       3.84
# 18382   194094    Lightning Charging Cable             1      14.95
#
#            Order Date                        Purchase Address
# 0      04/19/19 08:46            917 1st St, Dallas, TX 75001
# ...

# %%
df.iloc[0]#location of row
# Out:
# Order ID                                    193018
# Item                                  20in Monitor
# No. of Orders                                    1
# Price Each                                  109.99
# Order Date                        04-10-2019 19:58
# Purchase Address    378 Pine St, Seattle, WA 98101
# Name: 17245, dtype: object

# %%
df.shape
# Out:
# (18383, 6)

# %%
df.dropna()
# Out:
#       Order ID          Item No. of Orders Price Each        Order Date  \
# 17245   193018  20in Monitor             1     109.99  04-10-2019 19:58
# 17128   192906  20in Monitor             1     109.99    04/30/19 07:50
# 15175   191032  20in Monitor             1     109.99    04/20/19 21:44
# 17124   192902  20in Monitor             1     109.99  04-11-2019 07:56
# 325     176868  20in Monitor             1     109.99  04-05-2019 07:37
# ...        ...           ...           ...        ...               ...
# 7145    183376        iPhone             1        700    04/13/19 09:09
# 7142    183373        iPhone             1        700  04-09-2019 10:46
# 8583    184758        iPhone             1        700    04/13/19 20:02
# 1399    177888        iPhone             1        700  04-07-2019 18:11
# 14343   190235        iPhone             1        700  04-08-2019 21:53
#
#                                 Purchase Address
# 17245             378 Pine St, Seattle, WA 98101
# ...

# %%
import pandas as pd
df=pd.read_csv("forbes_billionaires.csv")
df
# Out:
#                           Name  NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
df.head()
# Out:
#                        Name  NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos     177.0  United States         Amazon     1
# 1                 Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family     150.0         France           LVMH     3
# 3                Bill Gates     124.0  United States      Microsoft     4
# 4           Mark Zuckerberg      97.0  United States       Facebook     5
#
#     Age              Residence    Citizenship           Status  Children  \
# 0  57.0    Seattle, Washington  United States  In Relationship       4.0
# 1  49.0          Austin, Texas  United States  In Relationship       7.0
# 2  72.0          Paris, France         France          Married       5.0
# 3  65.0     Medina, Washington  United States         Divorced       3.0
# 4  36.0  Palo Alto, California  United States          Married       2.0
#
#                                            Education Self_made
# ...

# %%
df.isnull().sum()
# Out:
# Name              0
# NetWorth          0
# Country           0
# Source            0
# Rank              0
# Age             125
# Residence        40
# Citizenship      16
# Status          665
# Children       1203
# Education      1346
# Self_made        18
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2750    False
# 2751    False
# 2752    False
# 2753    False
# 2754    False
# Length: 2755, dtype: bool

# %%
df[["Country","Name"]]
# Out:
#             Country                      Name
# 0     United States                Jeff Bezos
# 1     United States                 Elon Musk
# 2            France  Bernard Arnault & family
# 3     United States                Bill Gates
# 4     United States           Mark Zuckerberg
# ...             ...                       ...
# 2750          China         Daniel Yong Zhang
# 2751          China             Zhang Yuqiang
# 2752          China             Zhao Meiguang
# 2753          China            Zhong Naixiong
# 2754          China           Zhou Wei family
#
# [2755 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755 entries, 0 to 2754
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         2755 non-null   object
#  1   NetWorth     2755 non-null   float64
#  2   Country      2755 non-null   object
#  3   Source       2755 non-null   object
#  4   Rank         2755 non-null   int64
#  5   Age          2630 non-null   float64
#  6   Residence    2715 non-null   object
#  7   Citizenship  2739 non-null   object
#  8   Status       2090 non-null   object
#  9   Children     1552 non-null   float64
#  10  Education    1409 non-null   object
#  11  Self_made    2737 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 258.4+ KB

# %%
df.dtypes
# Out:
# Name            object
# NetWorth       float64
# Country         object
# Source          object
# Rank             int64
# Age            float64
# Residence       object
# Citizenship     object
# Status          object
# Children       float64
# Education       object
# Self_made       object
# dtype: object

# %%
df.dropna()
df.notnull().sum()
# Out:
# Name           2755
# NetWorth       2755
# Country        2755
# Source         2755
# Rank           2755
# Age            2630
# Residence      2715
# Citizenship    2739
# Status         2090
# Children       1552
# Education      1409
# Self_made      2737
# dtype: int64

# %%
df["Children"]
# Out:
# 0       4.0
# 1       7.0
# 2       5.0
# 3       3.0
# 4       2.0
#        ...
# 2750    NaN
# 2751    NaN
# 2752    NaN
# 2753    NaN
# 2754    NaN
# Name: Children, Length: 2755, dtype: float64

# %%
df.loc[2,"Name","NetWorth"]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df.loc[2,"Name","NetWorth"]
#
# File c:\Users\SUHAS S\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\SUHAS S\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1371, in _LocIndexer._getitem_tuple(self, tup)
#    1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
# -> 1371 tup = self._validate_tuple_indexer(tup)
#    1373 # ugly hack for GH #836
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (995, 12)

# %%
df.fillna(0,inplace=True)

# %%
df=df.rename(columns={"Country":"Nation"})

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.loc[0,"Nation"]
# Out:
# 'United States'

# %%
df["Nation"].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'Japan', 'Canada',
#        'Hong Kong', 'Russia', 'China', 'Germany', 'Austria', 'Sweden',
#        'Australia', 'Brazil', 'Netherlands', 'South Korea', 'Malaysia',
#        'Nigeria', 'Colombia', 'Italy', 'Denmark', 'Switzerland', 'Egypt',
#        'South Africa', 'United Kingdom', 'Ukraine', 'Ireland',
#        'Singapore', 'Taiwan', 'Indonesia', 'Norway', 'Turkey', 'Romania',
#        'Czechia', 'Israel', 'Eswatini (Swaziland)', 'Spain', 'Thailand',
#        'Philippines', 'Venezuela', 'Chile', 'Kazakhstan', 'Lebanon',
#        'Argentina', 'United Arab Emirates', 'Greece', 'Iceland', 'Poland',
#        'Morocco', 'Vietnam', 'Zimbabwe', 'Peru'], dtype=object)

# %%
df["Nation"].value_counts()
# Out:
# Nation
# United States           471
# Russia                  100
# India                    72
# China                    46
# South Korea              33
# Taiwan                   25
# Hong Kong                20
# Brazil                   18
# Germany                  16
# Canada                   16
# Australia                15
# Japan                    11
# Switzerland              10
# Malaysia                 10
# Sweden                    9
# United Kingdom            9
# Turkey                    8
# Italy                     8
# Mexico                    7
# Philippines               7
# Spain                     7
# Thailand                  6
# Ukraine                   6
# Israel                    6
# France                    5
# Czechia                   5
# Indonesia                 5
# Egypt                     5
# Chile                     3
# Singapore                 3
# Lebanon                   3
# Austria                   2
# Colombia                  2
# ...

# %%
df.loc[23,"Name"]
# Out:
# 'Gautam Adani & family'

# %%
df
# Out:
#                           Name  NetWorth         Nation  \
# 0                   Jeff Bezos     177.0  United States
# 1                    Elon Musk     151.0  United States
# 2     Bernard Arnault & family     150.0         France
# 3                   Bill Gates     124.0  United States
# 4              Mark Zuckerberg      97.0  United States
# ...                        ...       ...            ...
# 2736            Surin Upatkoon       1.0       Thailand
# 2737           Ruben Vardanyan       1.0         Russia
# 2742           J. Wayne Weaver       1.0  United States
# 2743               Sandy Weill       1.0  United States
# 2746             Vadim Yakunin       1.0         Russia
#
#                              Source  Rank   Age               Residence  \
# 0                            Amazon     1  57.0     Seattle, Washington
# 1                     Tesla, SpaceX     2  49.0           Austin, Texas
# 2                              LVMH     3  72.0           Paris, France
# ...

# %%
df["Status"]=df["Status"].fillna(method='bfill')
# Out:
# C:\Users\SUHAS S\AppData\Local\Temp\ipykernel_6104\193256210.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Status"]=df["Status"].fillna(method='bfill')

# %%
import warnings #To remove warnings
warnings.filterwarnings("ignore")

# %%
df["Nation"]+df["Residence"]
# Out:
# 0         United StatesSeattle, Washington
# 1               United StatesAustin, Texas
# 2                      FranceParis, France
# 3          United StatesMedina, Washington
# 4       United StatesPalo Alto, California
#                        ...
# 2736        ThailandKuala Lumpur, Malaysia
# 2737                  RussiaMoscow, Russia
# 2742    United StatesJacksonville, Florida
# 2743       United StatesSonoma, California
# 2746                  RussiaMoscow, Russia
# Length: 995, dtype: object

# %%
df["address"]=df["Nation"]+', '+df["Residence"]
df
# Out:
#                           Name  NetWorth         Nation  \
# 0                   Jeff Bezos     177.0  United States
# 1                    Elon Musk     151.0  United States
# 2     Bernard Arnault & family     150.0         France
# 3                   Bill Gates     124.0  United States
# 4              Mark Zuckerberg      97.0  United States
# ...                        ...       ...            ...
# 2736            Surin Upatkoon       1.0       Thailand
# 2737           Ruben Vardanyan       1.0         Russia
# 2742           J. Wayne Weaver       1.0  United States
# 2743               Sandy Weill       1.0  United States
# 2746             Vadim Yakunin       1.0         Russia
#
#                              Source  Rank   Age               Residence  \
# 0                            Amazon     1  57.0     Seattle, Washington
# 1                     Tesla, SpaceX     2  49.0           Austin, Texas
# 2                              LVMH     3  72.0           Paris, France
# ...

# %%
df[df["Age"]<30]
# Out:
#                       Name  NetWorth         Nation             Source  Rank  \
# 274      Sam Bankman-Fried       8.7  United States     cryptocurrency   274
# 661   Gustav Magnar Witzoe       4.4         Norway       fish farming   655
# 940    Kevin David Lehmann       3.3        Germany         drugstores   925
# 1328         Jonathan Kwok       2.4      Hong Kong        Real Estate  1299
# 1338        Austin Russell       2.4  United States                  ★  1299
# 1596             Andy Fang       2.0  United States  food delivery app  1580
# 1645          Stanley Tang       2.0  United States  food delivery app  1580
# 2122           Wang Zelong       1.5          China          chemicals  2035
# 2143    Alexandra Andresen       1.4         Norway        investments  2141
# 2144    Katharina Andresen       1.4         Norway        investments  2141
#
#        Age                  Residence    Citizenship   Status  Children  \
# ...

# %%
df[df["Nation"]=="United States"]
# Out:
#                  Name  NetWorth         Nation              Source  Rank  \
# 0          Jeff Bezos     177.0  United States              Amazon     1
# 1           Elon Musk     151.0  United States       Tesla, SpaceX     2
# 3          Bill Gates     124.0  United States           Microsoft     4
# 4     Mark Zuckerberg      97.0  United States            Facebook     5
# 5      Warren Buffett      96.0  United States  Berkshire Hathaway     6
# ...               ...       ...            ...                 ...   ...
# 2685       Larry Fink       1.0  United States    money management  2674
# 2702          Bom Kim       1.0  United States    online retailing  2674
# 2732       Vlad Tenev       1.0  United States       stock trading  2674
# 2742  J. Wayne Weaver       1.0  United States               Shoes  2674
# 2743      Sandy Weill       1.0  United States           Citigroup  2674
#
#        Age              Residence    Citizenship              Status  \
# ...

# %%
df
# Out:
#                           Name  NetWorth         Nation         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
df.groupby("Nation")["Age"].mean()
# Out:
# Nation
# Algeria           77.000000
# Argentina         85.750000
# Australia         65.348837
# Austria           69.583333
# Belgium           61.000000
#                     ...
# United Kingdom    66.754717
# United States     66.101551
# Venezuela         61.000000
# Vietnam           55.000000
# Zimbabwe          60.000000
# Name: Age, Length: 70, dtype: float64

# %%
df.groupby("Nation")["Age"].sum()
# Out:
# Nation
# Argentina                  85.0
# Australia                1007.0
# Austria                   157.0
# Brazil                   1250.0
# Canada                   1174.0
# Chile                     213.0
# China                    2707.0
# Colombia                  151.0
# Czechia                   269.0
# Denmark                    73.0
# Egypt                     333.0
# Eswatini (Swaziland)       89.0
# France                    377.0
# Germany                  1070.0
# Greece                     59.0
# Hong Kong                1393.0
# Iceland                    54.0
# India                    4926.0
# Indonesia                 339.0
# Ireland                   127.0
# Israel                    358.0
# Italy                     617.0
# Japan                     743.0
# Kazakhstan                107.0
# Lebanon                   183.0
# Malaysia                  776.0
# Mexico                    497.0
# Morocco                   148.0
# Netherlands               153.0
# ...

# %%
df.groupby("Nation")["Age"].min()
# Out:
# Nation
# Argentina               85.0
# Australia               41.0
# Austria                 76.0
# Brazil                  39.0
# Canada                  57.0
# Chile                   70.0
# China                   47.0
# Colombia                63.0
# Czechia                 45.0
# Denmark                 73.0
# Egypt                   59.0
# Eswatini (Swaziland)    89.0
# France                  67.0
# Germany                 46.0
# Greece                  59.0
# Hong Kong               35.0
# Iceland                 54.0
# India                   38.0
# Indonesia               58.0
# Ireland                 63.0
# Israel                  44.0
# Italy                   68.0
# Japan                   56.0
# Kazakhstan              53.0
# Lebanon                 42.0
# Malaysia                63.0
# Mexico                  58.0
# Morocco                 60.0
# Netherlands             66.0
# Nigeria                 64.0
# Norway                  60.0
# ...

# %%
df["Age"].min()
# Out:
# np.float64(18.0)

# %%
df["Age"].max()
# Out:
# np.float64(99.0)

# %%
df["United States"].mode()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\SUHAS S\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'United States'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ...

# %%
df["Nation"].value_counts().head(1)
# Out:
# Nation
# United States    724
# Name: count, dtype: int64

# %%
#which country has most billionares
df["Nation"].value_counts().head(5)
# Out:
# Nation
# United States    724
# China            626
# India            140
# Germany          136
# Russia           118
# Name: count, dtype: int64

# %%
pd.set_option("display.max_rows",None)
df
# Out:
#                                         Name  NetWorth                Nation  \
# 0                                 Jeff Bezos     177.0         United States
# 1                                  Elon Musk     151.0         United States
# 2                   Bernard Arnault & family     150.0                France
# 3                                 Bill Gates     124.0         United States
# 4                            Mark Zuckerberg      97.0         United States
# 5                             Warren Buffett      96.0         United States
# 6                              Larry Ellison      93.0         United States
# 7                                 Larry Page      91.5         United States
# 8                                Sergey Brin      89.0         United States
# 9                              Mukesh Ambani      84.5                 India
# 10                            Amancio Ortega      77.0                 Spain
# ...
